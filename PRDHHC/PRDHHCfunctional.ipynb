# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import random
from PIL import Image
import os
import csv
import sklearn.metrics as skm

# %% [markdown]
# ### 取得原始影像資料
#
# 1. 將影像轉成灰階
# 2. 轉換成二維像素陣列

# %%
def getImageArray(dirName):
    imageArray=[]
    for imageName in os.listdir(dirName):
        imageArray.append(cv2.imread(dirName+'/'+imageName))
    return imageArray,len(imageArray)

# %%
def getResizeImageArray():
    imageResizeArray=[]
    imageArray,imageArrayLength=getImageArray('../database/resizeImage')
    for image in imageArray:
        imageResizeArray.append(cv2.cvtColor(image,cv2.COLOR_BGR2GRAY))
    return imageResizeArray,imageArrayLength

# %%
imageArray,imageArrayLength=getResizeImageArray()
testImage=imageArray[0]

# %% [markdown]
# ### 取得資訊
#
# 1. 取得加密訊息
# 2. 轉為ascii碼
# 3. 轉換為二進制序列(0bxxxxxxx)
# 4. 去除0b
# 5. 向右對齊補0
# 6. 存入變數

# %%
def getMessage(txtPath):
    byteNumber=0
    with open(txtPath,"rb")  as file:
        txt = file.read()
        byteNumber=len(txt)
        charMessage=""
        for index in range(len(txt)):
            charMessage=charMessage+""+str(bin(txt[index]).replace('0b','')).zfill(7)
            if(index<10):
                print('第'+str(index)+'位為:  '+chr(txt[index])+', 二進制為: '+str(bin(txt[index]).replace('0b','')).zfill(7))
            else:
                print('第'+str(index)+'位為: '+chr(txt[index])+', 二進制為: '+str(bin(txt[index]).replace('0b','')).zfill(7))
    print("輸出為："+charMessage) 
    print("字元數："+str(byteNumber)) 
    print("位元數："+str(len(charMessage))) 
    return charMessage

# %%
message=getMessage("../message/1024message.txt")
# Out:
# 第0位為:  N, 二進制為: 1001110
# 第1位為:  I, 二進制為: 1001001
# 第2位為:  U, 二進制為: 1010101
# 第3位為:  1, 二進制為: 0110001
# 第4位為:  1, 二進制為: 0110001
# 第5位為:  1, 二進制為: 0110001
# 第6位為:  2, 二進制為: 0110010
# 第7位為:  C, 二進制為: 1000011
# 第8位為:  r, 二進制為: 1110010
# 第9位為:  y, 二進制為: 1111001
# 第10位為: p, 二進制為: 1110000
# 第11位為: t, 二進制為: 1110100
# 第12位為: o, 二進制為: 1101111
# 第13位為: g, 二進制為: 1100111
# 第14位為: r, 二進制為: 1110010
# 第15位為: a, 二進制為: 1100001
# 第16位為: p, 二進制為: 1110000
# 第17位為: h, 二進制為: 1101000
# 第18位為: y, 二進制為: 1111001
# 第19位為: N, 二進制為: 1001110
# 第20位為: I, 二進制為: 1001001
# 第21位為: U, 二進制為: 1010101
# 第22位為: 1, 二進制為: 0110001
# 第23位為: 1, 二進制為: 0110001
# 第24位為: 1, 二進制為: 0110001
# 第25位為: 2, 二進制為: 0110010
# 第26位為: C, 二進制為: 1000011
# 第27位為: r, 二進制為: 1110010
# 第28位為: y, 二進制為: 1111001
# 第29位為: p, 二進制為: 1110000
# 第30位為: t, 二進制為: 1110100
# 第31位為: o, 二進制為: 1101111
# 第32位為: g, 二進制為: 1100111
# 第33位為: r, 二進制為: 1110010
# 第34位為: a, 二進制為: 1100001
# 第35位為: p, 二進制為: 1110000
# 第36位為: h, 二進制為: 1101000
# 第37位為: y, 二進制為: 1111001
# 第38位為: N, 二進制為: 1001110
# 第39位為: I, 二進制為: 1001001
# 第40位為: U, 二進制為: 1010101
# 第41位為: 1, 二進制為: 0110001
# 第42位為: 1, 二進制為: 0110001
# 第43位為: 1, 二進制為: 0110001
# 第44位為: 2, 二進制為: 0110010
# 第45位為: C, 二進制為: 1000011
# 第46位為: r, 二進制為: 1110010
# 第47位為: y, 二進制為: 1111001
# 第48位為: p, 二進制為: 1110000
# 第49位為: t, 二進制為: 1110100
# 第50位為: o, 二進制為: 1101111
# 第51位為: g, 二進制為: 1100111
# 第52位為: r, 二進制為: 1110010
# 第53位為: a, 二進制為: 1100001
# 第54位為: p, 二進制為: 1110000
# 第55位為: h, 二進制為: 1101000
# 第56位為: y, 二進制為: 1111001
# 第57位為: N, 二進制為: 1001110
# 第58位為: I, 二進制為: 1001001
# 第59位為: U, 二進制為: 1010101
# 第60位為: 1, 二進制為: 0110001
# 第61位為: 1, 二進制為: 0110001
# 第62位為: 1, 二進制為: 0110001
# 第63位為: 2, 二進制為: 0110010
# 第64位為: C, 二進制為: 1000011
# 第65位為: r, 二進制為: 1110010
# 第66位為: y, 二進制為: 1111001
# 第67位為: p, 二進制為: 1110000
# 第68位為: t, 二進制為: 1110100
# 第69位為: o, 二進制為: 1101111
# 第70位為: g, 二進制為: 1100111
# 第71位為: r, 二進制為: 1110010
# 第72位為: a, 二進制為: 1100001
# 第73位為: p, 二進制為: 1110000
# 第74位為: h, 二進制為: 1101000
# 第75位為: y, 二進制為: 1111001
# 第76位為: N, 二進制為: 1001110
# 第77位為: I, 二進制為: 1001001
# 第78位為: U, 二進制為: 1010101
# 第79位為: 1, 二進制為: 0110001
# 第80位為: 1, 二進制為: 0110001
# 第81位為: 1, 二進制為: 0110001
# 第82位為: 2, 二進制為: 0110010
# 第83位為: C, 二進制為: 1000011
# 第84位為: r, 二進制為: 1110010
# 第85位為: y, 二進制為: 1111001
# 第86位為: p, 二進制為: 1110000
# 第87位為: t, 二進制為: 1110100
# 第88位為: o, 二進制為: 1101111
# 第89位為: g, 二進制為: 1100111
# 第90位為: r, 二進制為: 1110010
# 第91位為: a, 二進制為: 1100001
# 第92位為: p, 二進制為: 1110000
# 第93位為: h, 二進制為: 1101000
# 第94位為: y, 二進制為: 1111001
# 第95位為: N, 二進制為: 1001110
# 第96位為: I, 二進制為: 1001001
# 第97位為: U, 二進制為: 1010101
# 第98位為: 1, 二進制為: 0110001
# 第99位為: 1, 二進制為: 0110001
# 第100位為: 1, 二進制為: 0110001
# 第101位為: 2, 二進制為: 0110010
# 第102位為: C, 二進制為: 1000011
# 第103位為: r, 二進制為: 1110010
# 第104位為: y, 二進制為: 1111001
# 第105位為: p, 二進制為: 1110000
# 第106位為: t, 二進制為: 1110100
# 第107位為: o, 二進制為: 1101111
# 第108位為: g, 二進制為: 1100111
# 第109位為: r, 二進制為: 1110010
# 第110位為: a, 二進制為: 1100001
# 第111位為: p, 二進制為: 1110000
# 第112位為: h, 二進制為: 1101000
# 第113位為: y, 二進制為: 1111001
# 第114位為: N, 二進制為: 1001110
# 第115位為: I, 二進制為: 1001001
# 第116位為: U, 二進制為: 1010101
# 第117位為: 1, 二進制為: 0110001
# 第118位為: 1, 二進制為: 0110001
# 第119位為: 1, 二進制為: 0110001
# 第120位為: 2, 二進制為: 0110010
# 第121位為: C, 二進制為: 1000011
# 第122位為: r, 二進制為: 1110010
# 第123位為: y, 二進制為: 1111001
# 第124位為: p, 二進制為: 1110000
# 第125位為: t, 二進制為: 1110100
# 第126位為: o, 二進制為: 1101111
# 第127位為: g, 二進制為: 1100111
# 第128位為: r, 二進制為: 1110010
# 第129位為: a, 二進制為: 1100001
# 第130位為: p, 二進制為: 1110000
# 第131位為: h, 二進制為: 1101000
# 第132位為: y, 二進制為: 1111001
# 第133位為: N, 二進制為: 1001110
# 第134位為: I, 二進制為: 1001001
# 第135位為: U, 二進制為: 1010101
# 第136位為: 1, 二進制為: 0110001
# 第137位為: 1, 二進制為: 0110001
# 第138位為: 1, 二進制為: 0110001
# 第139位為: 2, 二進制為: 0110010
# 第140位為: C, 二進制為: 1000011
# 第141位為: r, 二進制為: 1110010
# 第142位為: y, 二進制為: 1111001
# 第143位為: p, 二進制為: 1110000
# 第144位為: t, 二進制為: 1110100
# 第145位為: o, 二進制為: 1101111
# 第146位為: g, 二進制為: 1100111
# 第147位為: r, 二進制為: 1110010
# 第148位為: a, 二進制為: 1100001
# 第149位為: p, 二進制為: 1110000
# 第150位為: h, 二進制為: 1101000
# 第151位為: y, 二進制為: 1111001
# 第152位為: N, 二進制為: 1001110
# 第153位為: I, 二進制為: 1001001
# 第154位為: U, 二進制為: 1010101
# 第155位為: 1, 二進制為: 0110001
# 第156位為: 1, 二進制為: 0110001
# 第157位為: 1, 二進制為: 0110001
# 第158位為: 2, 二進制為: 0110010
# 第159位為: C, 二進制為: 1000011
# 第160位為: r, 二進制為: 1110010
# 第161位為: y, 二進制為: 1111001
# 第162位為: p, 二進制為: 1110000
# 第163位為: t, 二進制為: 1110100
# 第164位為: o, 二進制為: 1101111
# 第165位為: g, 二進制為: 1100111
# 第166位為: r, 二進制為: 1110010
# 第167位為: a, 二進制為: 1100001
# 第168位為: p, 二進制為: 1110000
# 第169位為: h, 二進制為: 1101000
# 第170位為: y, 二進制為: 1111001
# 第171位為: N, 二進制為: 1001110
# 第172位為: I, 二進制為: 1001001
# 第173位為: U, 二進制為: 1010101
# 第174位為: 1, 二進制為: 0110001
# 第175位為: 1, 二進制為: 0110001
# 第176位為: 1, 二進制為: 0110001
# 第177位為: 2, 二進制為: 0110010
# 第178位為: C, 二進制為: 1000011
# 第179位為: r, 二進制為: 1110010
# 第180位為: y, 二進制為: 1111001
# 第181位為: p, 二進制為: 1110000
# 第182位為: t, 二進制為: 1110100
# 第183位為: o, 二進制為: 1101111
# 第184位為: g, 二進制為: 1100111
# 第185位為: r, 二進制為: 1110010
# 第186位為: a, 二進制為: 1100001
# 第187位為: p, 二進制為: 1110000
# 第188位為: h, 二進制為: 1101000
# 第189位為: y, 二進制為: 1111001
# 第190位為: N, 二進制為: 1001110
# 第191位為: I, 二進制為: 1001001
# 第192位為: U, 二進制為: 1010101
# 第193位為: 1, 二進制為: 0110001
# 第194位為: 1, 二進制為: 0110001
# 第195位為: 1, 二進制為: 0110001
# 第196位為: 2, 二進制為: 0110010
# 第197位為: C, 二進制為: 1000011
# 第198位為: r, 二進制為: 1110010
# 第199位為: y, 二進制為: 1111001
# 第200位為: p, 二進制為: 1110000
# 第201位為: t, 二進制為: 1110100
# 第202位為: o, 二進制為: 1101111
# 第203位為: g, 二進制為: 1100111
# 第204位為: r, 二進制為: 1110010
# 第205位為: a, 二進制為: 1100001
# 第206位為: p, 二進制為: 1110000
# 第207位為: h, 二進制為: 1101000
# 第208位為: y, 二進制為: 1111001
# 第209位為: N, 二進制為: 1001110
# 第210位為: I, 二進制為: 1001001
# 第211位為: U, 二進制為: 1010101
# 第212位為: 1, 二進制為: 0110001
# 第213位為: 1, 二進制為: 0110001
# 第214位為: 1, 二進制為: 0110001
# 第215位為: 2, 二進制為: 0110010
# 第216位為: C, 二進制為: 1000011
# 第217位為: r, 二進制為: 1110010
# 第218位為: y, 二進制為: 1111001
# 第219位為: p, 二進制為: 1110000
# 第220位為: t, 二進制為: 1110100
# 第221位為: o, 二進制為: 1101111
# 第222位為: g, 二進制為: 1100111
# 第223位為: r, 二進制為: 1110010
# 第224位為: a, 二進制為: 1100001
# 第225位為: p, 二進制為: 1110000
# 第226位為: h, 二進制為: 1101000
# 第227位為: y, 二進制為: 1111001
# 第228位為: N, 二進制為: 1001110
# 第229位為: I, 二進制為: 1001001
# 第230位為: U, 二進制為: 1010101
# 第231位為: 1, 二進制為: 0110001
# 第232位為: 1, 二進制為: 0110001
# 第233位為: 1, 二進制為: 0110001
# 第234位為: 2, 二進制為: 0110010
# 第235位為: C, 二進制為: 1000011
# 第236位為: r, 二進制為: 1110010
# 第237位為: y, 二進制為: 1111001
# 第238位為: p, 二進制為: 1110000
# 第239位為: t, 二進制為: 1110100
# 第240位為: o, 二進制為: 1101111
# 第241位為: g, 二進制為: 1100111
# 第242位為: r, 二進制為: 1110010
# 第243位為: a, 二進制為: 1100001
# 第244位為: p, 二進制為: 1110000
# 第245位為: h, 二進制為: 1101000
# 第246位為: y, 二進制為: 1111001
# 第247位為: N, 二進制為: 1001110
# 第248位為: I, 二進制為: 1001001
# 第249位為: U, 二進制為: 1010101
# 第250位為: 1, 二進制為: 0110001
# 第251位為: 1, 二進制為: 0110001
# 第252位為: 1, 二進制為: 0110001
# 第253位為: 2, 二進制為: 0110010
# 第254位為: C, 二進制為: 1000011
# 第255位為: r, 二進制為: 1110010
# 第256位為: y, 二進制為: 1111001
# 第257位為: p, 二進制為: 1110000
# 第258位為: t, 二進制為: 1110100
# 第259位為: o, 二進制為: 1101111
# 第260位為: g, 二進制為: 1100111
# 第261位為: r, 二進制為: 1110010
# 第262位為: a, 二進制為: 1100001
# 第263位為: p, 二進制為: 1110000
# 第264位為: h, 二進制為: 1101000
# 第265位為: y, 二進制為: 1111001
# 第266位為: N, 二進制為: 1001110
# 第267位為: I, 二進制為: 1001001
# 第268位為: U, 二進制為: 1010101
# 第269位為: 1, 二進制為: 0110001
# 第270位為: 1, 二進制為: 0110001
# 第271位為: 1, 二進制為: 0110001
# 第272位為: 2, 二進制為: 0110010
# 第273位為: C, 二進制為: 1000011
# 第274位為: r, 二進制為: 1110010
# 第275位為: y, 二進制為: 1111001
# 第276位為: p, 二進制為: 1110000
# 第277位為: t, 二進制為: 1110100
# 第278位為: o, 二進制為: 1101111
# 第279位為: g, 二進制為: 1100111
# 第280位為: r, 二進制為: 1110010
# 第281位為: a, 二進制為: 1100001
# 第282位為: p, 二進制為: 1110000
# 第283位為: h, 二進制為: 1101000
# 第284位為: y, 二進制為: 1111001
# 第285位為: N, 二進制為: 1001110
# 第286位為: I, 二進制為: 1001001
# 第287位為: U, 二進制為: 1010101
# 第288位為: 1, 二進制為: 0110001
# 第289位為: 1, 二進制為: 0110001
# 第290位為: 1, 二進制為: 0110001
# 第291位為: 2, 二進制為: 0110010
# 第292位為: C, 二進制為: 1000011
# 第293位為: r, 二進制為: 1110010
# 第294位為: y, 二進制為: 1111001
# 第295位為: p, 二進制為: 1110000
# 第296位為: t, 二進制為: 1110100
# 第297位為: o, 二進制為: 1101111
# 第298位為: g, 二進制為: 1100111
# 第299位為: r, 二進制為: 1110010
# 第300位為: a, 二進制為: 1100001
# 第301位為: p, 二進制為: 1110000
# 第302位為: h, 二進制為: 1101000
# 第303位為: y, 二進制為: 1111001
# 第304位為: N, 二進制為: 1001110
# 第305位為: I, 二進制為: 1001001
# 第306位為: U, 二進制為: 1010101
# 第307位為: 1, 二進制為: 0110001
# 第308位為: 1, 二進制為: 0110001
# 第309位為: 1, 二進制為: 0110001
# 第310位為: 2, 二進制為: 0110010
# 第311位為: C, 二進制為: 1000011
# 第312位為: r, 二進制為: 1110010
# 第313位為: y, 二進制為: 1111001
# 第314位為: p, 二進制為: 1110000
# 第315位為: t, 二進制為: 1110100
# 第316位為: o, 二進制為: 1101111
# 第317位為: g, 二進制為: 1100111
# 第318位為: r, 二進制為: 1110010
# 第319位為: a, 二進制為: 1100001
# 第320位為: p, 二進制為: 1110000
# 第321位為: h, 二進制為: 1101000
# 第322位為: y, 二進制為: 1111001
# 第323位為: N, 二進制為: 1001110
# 第324位為: I, 二進制為: 1001001
# 第325位為: U, 二進制為: 1010101
# 第326位為: 1, 二進制為: 0110001
# 第327位為: 1, 二進制為: 0110001
# 第328位為: 1, 二進制為: 0110001
# 第329位為: 2, 二進制為: 0110010
# 第330位為: C, 二進制為: 1000011
# 第331位為: r, 二進制為: 1110010
# 第332位為: y, 二進制為: 1111001
# 第333位為: p, 二進制為: 1110000
# 第334位為: t, 二進制為: 1110100
# 第335位為: o, 二進制為: 1101111
# 第336位為: g, 二進制為: 1100111
# 第337位為: r, 二進制為: 1110010
# 第338位為: a, 二進制為: 1100001
# 第339位為: p, 二進制為: 1110000
# 第340位為: h, 二進制為: 1101000
# 第341位為: y, 二進制為: 1111001
# 第342位為: N, 二進制為: 1001110
# 第343位為: I, 二進制為: 1001001
# 第344位為: U, 二進制為: 1010101
# 第345位為: 1, 二進制為: 0110001
# 第346位為: 1, 二進制為: 0110001
# 第347位為: 1, 二進制為: 0110001
# 第348位為: 2, 二進制為: 0110010
# 第349位為: C, 二進制為: 1000011
# 第350位為: r, 二進制為: 1110010
# 第351位為: y, 二進制為: 1111001
# 第352位為: p, 二進制為: 1110000
# 第353位為: t, 二進制為: 1110100
# 第354位為: o, 二進制為: 1101111
# 第355位為: g, 二進制為: 1100111
# 第356位為: r, 二進制為: 1110010
# 第357位為: a, 二進制為: 1100001
# 第358位為: p, 二進制為: 1110000
# 第359位為: h, 二進制為: 1101000
# 第360位為: y, 二進制為: 1111001
# 第361位為: N, 二進制為: 1001110
# 第362位為: I, 二進制為: 1001001
# 第363位為: U, 二進制為: 1010101
# 第364位為: 1, 二進制為: 0110001
# 第365位為: 1, 二進制為: 0110001
# 第366位為: 1, 二進制為: 0110001
# 第367位為: 2, 二進制為: 0110010
# 第368位為: C, 二進制為: 1000011
# 第369位為: r, 二進制為: 1110010
# 第370位為: y, 二進制為: 1111001
# 第371位為: p, 二進制為: 1110000
# 第372位為: t, 二進制為: 1110100
# 第373位為: o, 二進制為: 1101111
# 第374位為: g, 二進制為: 1100111
# 第375位為: r, 二進制為: 1110010
# 第376位為: a, 二進制為: 1100001
# 第377位為: p, 二進制為: 1110000
# 第378位為: h, 二進制為: 1101000
# 第379位為: y, 二進制為: 1111001
# 第380位為: N, 二進制為: 1001110
# 第381位為: I, 二進制為: 1001001
# 第382位為: U, 二進制為: 1010101
# 第383位為: 1, 二進制為: 0110001
# 第384位為: 1, 二進制為: 0110001
# 第385位為: 1, 二進制為: 0110001
# 第386位為: 2, 二進制為: 0110010
# 第387位為: C, 二進制為: 1000011
# 第388位為: r, 二進制為: 1110010
# 第389位為: y, 二進制為: 1111001
# 第390位為: p, 二進制為: 1110000
# 第391位為: t, 二進制為: 1110100
# 第392位為: o, 二進制為: 1101111
# 第393位為: g, 二進制為: 1100111
# 第394位為: r, 二進制為: 1110010
# 第395位為: a, 二進制為: 1100001
# 第396位為: p, 二進制為: 1110000
# 第397位為: h, 二進制為: 1101000
# 第398位為: y, 二進制為: 1111001
# 第399位為: N, 二進制為: 1001110
# 第400位為: I, 二進制為: 1001001
# 第401位為: U, 二進制為: 1010101
# 第402位為: 1, 二進制為: 0110001
# 第403位為: 1, 二進制為: 0110001
# 第404位為: 1, 二進制為: 0110001
# 第405位為: 2, 二進制為: 0110010
# 第406位為: C, 二進制為: 1000011
# 第407位為: r, 二進制為: 1110010
# 第408位為: y, 二進制為: 1111001
# 第409位為: p, 二進制為: 1110000
# 第410位為: t, 二進制為: 1110100
# 第411位為: o, 二進制為: 1101111
# 第412位為: g, 二進制為: 1100111
# 第413位為: r, 二進制為: 1110010
# 第414位為: a, 二進制為: 1100001
# 第415位為: p, 二進制為: 1110000
# 第416位為: h, 二進制為: 1101000
# 第417位為: y, 二進制為: 1111001
# 第418位為: N, 二進制為: 1001110
# 第419位為: I, 二進制為: 1001001
# 第420位為: U, 二進制為: 1010101
# 第421位為: 1, 二進制為: 0110001
# 第422位為: 1, 二進制為: 0110001
# 第423位為: 1, 二進制為: 0110001
# 第424位為: 2, 二進制為: 0110010
# 第425位為: C, 二進制為: 1000011
# 第426位為: r, 二進制為: 1110010
# 第427位為: y, 二進制為: 1111001
# 第428位為: p, 二進制為: 1110000
# 第429位為: t, 二進制為: 1110100
# 第430位為: o, 二進制為: 1101111
# 第431位為: g, 二進制為: 1100111
# 第432位為: r, 二進制為: 1110010
# 第433位為: a, 二進制為: 1100001
# 第434位為: p, 二進制為: 1110000
# 第435位為: h, 二進制為: 1101000
# 第436位為: y, 二進制為: 1111001
# 第437位為: N, 二進制為: 1001110
# 第438位為: I, 二進制為: 1001001
# 第439位為: U, 二進制為: 1010101
# 第440位為: 1, 二進制為: 0110001
# 第441位為: 1, 二進制為: 0110001
# 第442位為: 1, 二進制為: 0110001
# 第443位為: 2, 二進制為: 0110010
# 第444位為: C, 二進制為: 1000011
# 第445位為: r, 二進制為: 1110010
# 第446位為: y, 二進制為: 1111001
# 第447位為: p, 二進制為: 1110000
# 第448位為: t, 二進制為: 1110100
# 第449位為: o, 二進制為: 1101111
# 第450位為: g, 二進制為: 1100111
# 第451位為: r, 二進制為: 1110010
# 第452位為: a, 二進制為: 1100001
# 第453位為: p, 二進制為: 1110000
# 第454位為: h, 二進制為: 1101000
# 第455位為: y, 二進制為: 1111001
# 第456位為: N, 二進制為: 1001110
# 第457位為: I, 二進制為: 1001001
# 第458位為: U, 二進制為: 1010101
# 第459位為: 1, 二進制為: 0110001
# 第460位為: 1, 二進制為: 0110001
# 第461位為: 1, 二進制為: 0110001
# 第462位為: 2, 二進制為: 0110010
# 第463位為: C, 二進制為: 1000011
# 第464位為: r, 二進制為: 1110010
# 第465位為: y, 二進制為: 1111001
# 第466位為: p, 二進制為: 1110000
# 第467位為: t, 二進制為: 1110100
# 第468位為: o, 二進制為: 1101111
# 第469位為: g, 二進制為: 1100111
# 第470位為: r, 二進制為: 1110010
# 第471位為: a, 二進制為: 1100001
# 第472位為: p, 二進制為: 1110000
# 第473位為: h, 二進制為: 1101000
# 第474位為: y, 二進制為: 1111001
# 第475位為: N, 二進制為: 1001110
# 第476位為: I, 二進制為: 1001001
# 第477位為: U, 二進制為: 1010101
# 第478位為: 1, 二進制為: 0110001
# 第479位為: 1, 二進制為: 0110001
# 第480位為: 1, 二進制為: 0110001
# 第481位為: 2, 二進制為: 0110010
# 第482位為: C, 二進制為: 1000011
# 第483位為: r, 二進制為: 1110010
# 第484位為: y, 二進制為: 1111001
# 第485位為: p, 二進制為: 1110000
# 第486位為: t, 二進制為: 1110100
# 第487位為: o, 二進制為: 1101111
# 第488位為: g, 二進制為: 1100111
# 第489位為: r, 二進制為: 1110010
# 第490位為: a, 二進制為: 1100001
# 第491位為: p, 二進制為: 1110000
# 第492位為: h, 二進制為: 1101000
# 第493位為: y, 二進制為: 1111001
# 第494位為: N, 二進制為: 1001110
# 第495位為: I, 二進制為: 1001001
# 第496位為: U, 二進制為: 1010101
# 第497位為: 1, 二進制為: 0110001
# 第498位為: 1, 二進制為: 0110001
# 第499位為: 1, 二進制為: 0110001
# 第500位為: 2, 二進制為: 0110010
# 第501位為: C, 二進制為: 1000011
# 第502位為: r, 二進制為: 1110010
# 第503位為: y, 二進制為: 1111001
# 第504位為: p, 二進制為: 1110000
# 第505位為: t, 二進制為: 1110100
# 第506位為: o, 二進制為: 1101111
# 第507位為: g, 二進制為: 1100111
# 第508位為: r, 二進制為: 1110010
# 第509位為: a, 二進制為: 1100001
# 第510位為: p, 二進制為: 1110000
# 第511位為: h, 二進制為: 1101000
# 第512位為: y, 二進制為: 1111001
# 第513位為: N, 二進制為: 1001110
# 第514位為: I, 二進制為: 1001001
# 第515位為: U, 二進制為: 1010101
# 第516位為: 1, 二進制為: 0110001
# 第517位為: 1, 二進制為: 0110001
# 第518位為: 1, 二進制為: 0110001
# 第519位為: 2, 二進制為: 0110010
# 第520位為: C, 二進制為: 1000011
# 第521位為: r, 二進制為: 1110010
# 第522位為: y, 二進制為: 1111001
# 第523位為: p, 二進制為: 1110000
# 第524位為: t, 二進制為: 1110100
# 第525位為: o, 二進制為: 1101111
# 第526位為: g, 二進制為: 1100111
# 第527位為: r, 二進制為: 1110010
# 第528位為: a, 二進制為: 1100001
# 第529位為: p, 二進制為: 1110000
# 第530位為: h, 二進制為: 1101000
# 第531位為: y, 二進制為: 1111001
# 第532位為: N, 二進制為: 1001110
# 第533位為: I, 二進制為: 1001001
# 第534位為: U, 二進制為: 1010101
# 第535位為: 1, 二進制為: 0110001
# 第536位為: 1, 二進制為: 0110001
# 第537位為: 1, 二進制為: 0110001
# 第538位為: 2, 二進制為: 0110010
# 第539位為: C, 二進制為: 1000011
# 第540位為: r, 二進制為: 1110010
# 第541位為: y, 二進制為: 1111001
# 第542位為: p, 二進制為: 1110000
# 第543位為: t, 二進制為: 1110100
# 第544位為: o, 二進制為: 1101111
# 第545位為: g, 二進制為: 1100111
# 第546位為: r, 二進制為: 1110010
# 第547位為: a, 二進制為: 1100001
# 第548位為: p, 二進制為: 1110000
# 第549位為: h, 二進制為: 1101000
# 第550位為: y, 二進制為: 1111001
# 第551位為: N, 二進制為: 1001110
# 第552位為: I, 二進制為: 1001001
# 第553位為: U, 二進制為: 1010101
# 第554位為: 1, 二進制為: 0110001
# 第555位為: 1, 二進制為: 0110001
# 第556位為: 1, 二進制為: 0110001
# 第557位為: 2, 二進制為: 0110010
# 第558位為: C, 二進制為: 1000011
# 第559位為: r, 二進制為: 1110010
# 第560位為: y, 二進制為: 1111001
# 第561位為: p, 二進制為: 1110000
# 第562位為: t, 二進制為: 1110100
# 第563位為: o, 二進制為: 1101111
# 第564位為: g, 二進制為: 1100111
# 第565位為: r, 二進制為: 1110010
# 第566位為: a, 二進制為: 1100001
# 第567位為: p, 二進制為: 1110000
# 第568位為: h, 二進制為: 1101000
# 第569位為: y, 二進制為: 1111001
# 第570位為: N, 二進制為: 1001110
# 第571位為: I, 二進制為: 1001001
# 第572位為: U, 二進制為: 1010101
# 第573位為: 1, 二進制為: 0110001
# 第574位為: 1, 二進制為: 0110001
# 第575位為: 1, 二進制為: 0110001
# 第576位為: 2, 二進制為: 0110010
# 第577位為: C, 二進制為: 1000011
# 第578位為: r, 二進制為: 1110010
# 第579位為: y, 二進制為: 1111001
# 第580位為: p, 二進制為: 1110000
# 第581位為: t, 二進制為: 1110100
# 第582位為: o, 二進制為: 1101111
# 第583位為: g, 二進制為: 1100111
# 第584位為: r, 二進制為: 1110010
# 第585位為: a, 二進制為: 1100001
# 第586位為: p, 二進制為: 1110000
# 第587位為: h, 二進制為: 1101000
# 第588位為: y, 二進制為: 1111001
# 第589位為: N, 二進制為: 1001110
# 第590位為: I, 二進制為: 1001001
# 第591位為: U, 二進制為: 1010101
# 第592位為: 1, 二進制為: 0110001
# 第593位為: 1, 二進制為: 0110001
# 第594位為: 1, 二進制為: 0110001
# 第595位為: 2, 二進制為: 0110010
# 第596位為: C, 二進制為: 1000011
# 第597位為: r, 二進制為: 1110010
# 第598位為: y, 二進制為: 1111001
# 第599位為: p, 二進制為: 1110000
# 第600位為: t, 二進制為: 1110100
# 第601位為: o, 二進制為: 1101111
# 第602位為: g, 二進制為: 1100111
# 第603位為: r, 二進制為: 1110010
# 第604位為: a, 二進制為: 1100001
# 第605位為: p, 二進制為: 1110000
# 第606位為: h, 二進制為: 1101000
# 第607位為: y, 二進制為: 1111001
# 第608位為: N, 二進制為: 1001110
# 第609位為: I, 二進制為: 1001001
# 第610位為: U, 二進制為: 1010101
# 第611位為: 1, 二進制為: 0110001
# 第612位為: 1, 二進制為: 0110001
# 第613位為: 1, 二進制為: 0110001
# 第614位為: 2, 二進制為: 0110010
# 第615位為: C, 二進制為: 1000011
# 第616位為: r, 二進制為: 1110010
# 第617位為: y, 二進制為: 1111001
# 第618位為: p, 二進制為: 1110000
# 第619位為: t, 二進制為: 1110100
# 第620位為: o, 二進制為: 1101111
# 第621位為: g, 二進制為: 1100111
# 第622位為: r, 二進制為: 1110010
# 第623位為: a, 二進制為: 1100001
# 第624位為: p, 二進制為: 1110000
# 第625位為: h, 二進制為: 1101000
# 第626位為: y, 二進制為: 1111001
# 第627位為: N, 二進制為: 1001110
# 第628位為: I, 二進制為: 1001001
# 第629位為: U, 二進制為: 1010101
# 第630位為: 1, 二進制為: 0110001
# 第631位為: 1, 二進制為: 0110001
# 第632位為: 1, 二進制為: 0110001
# 第633位為: 2, 二進制為: 0110010
# 第634位為: C, 二進制為: 1000011
# 第635位為: r, 二進制為: 1110010
# 第636位為: y, 二進制為: 1111001
# 第637位為: p, 二進制為: 1110000
# 第638位為: t, 二進制為: 1110100
# 第639位為: o, 二進制為: 1101111
# 第640位為: g, 二進制為: 1100111
# 第641位為: r, 二進制為: 1110010
# 第642位為: a, 二進制為: 1100001
# 第643位為: p, 二進制為: 1110000
# 第644位為: h, 二進制為: 1101000
# 第645位為: y, 二進制為: 1111001
# 第646位為: N, 二進制為: 1001110
# 第647位為: I, 二進制為: 1001001
# 第648位為: U, 二進制為: 1010101
# 第649位為: 1, 二進制為: 0110001
# 第650位為: 1, 二進制為: 0110001
# 第651位為: 1, 二進制為: 0110001
# 第652位為: 2, 二進制為: 0110010
# 第653位為: C, 二進制為: 1000011
# 第654位為: r, 二進制為: 1110010
# 第655位為: y, 二進制為: 1111001
# 第656位為: p, 二進制為: 1110000
# 第657位為: t, 二進制為: 1110100
# 第658位為: o, 二進制為: 1101111
# 第659位為: g, 二進制為: 1100111
# 第660位為: r, 二進制為: 1110010
# 第661位為: a, 二進制為: 1100001
# 第662位為: p, 二進制為: 1110000
# 第663位為: h, 二進制為: 1101000
# 第664位為: y, 二進制為: 1111001
# 第665位為: N, 二進制為: 1001110
# 第666位為: I, 二進制為: 1001001
# 第667位為: U, 二進制為: 1010101
# 第668位為: 1, 二進制為: 0110001
# 第669位為: 1, 二進制為: 0110001
# 第670位為: 1, 二進制為: 0110001
# 第671位為: 2, 二進制為: 0110010
# 第672位為: C, 二進制為: 1000011
# 第673位為: r, 二進制為: 1110010
# 第674位為: y, 二進制為: 1111001
# 第675位為: p, 二進制為: 1110000
# 第676位為: t, 二進制為: 1110100
# 第677位為: o, 二進制為: 1101111
# 第678位為: g, 二進制為: 1100111
# 第679位為: r, 二進制為: 1110010
# 第680位為: a, 二進制為: 1100001
# 第681位為: p, 二進制為: 1110000
# 第682位為: h, 二進制為: 1101000
# 第683位為: y, 二進制為: 1111001
# 第684位為: N, 二進制為: 1001110
# 第685位為: I, 二進制為: 1001001
# 第686位為: U, 二進制為: 1010101
# 第687位為: 1, 二進制為: 0110001
# 第688位為: 1, 二進制為: 0110001
# 第689位為: 1, 二進制為: 0110001
# 第690位為: 2, 二進制為: 0110010
# 第691位為: C, 二進制為: 1000011
# 第692位為: r, 二進制為: 1110010
# 第693位為: y, 二進制為: 1111001
# 第694位為: p, 二進制為: 1110000
# 第695位為: t, 二進制為: 1110100
# 第696位為: o, 二進制為: 1101111
# 第697位為: g, 二進制為: 1100111
# 第698位為: r, 二進制為: 1110010
# 第699位為: a, 二進制為: 1100001
# 第700位為: p, 二進制為: 1110000
# 第701位為: h, 二進制為: 1101000
# 第702位為: y, 二進制為: 1111001
# 第703位為: N, 二進制為: 1001110
# 第704位為: I, 二進制為: 1001001
# 第705位為: U, 二進制為: 1010101
# 第706位為: 1, 二進制為: 0110001
# 第707位為: 1, 二進制為: 0110001
# 第708位為: 1, 二進制為: 0110001
# 第709位為: 2, 二進制為: 0110010
# 第710位為: C, 二進制為: 1000011
# 第711位為: r, 二進制為: 1110010
# 第712位為: y, 二進制為: 1111001
# 第713位為: p, 二進制為: 1110000
# 第714位為: t, 二進制為: 1110100
# 第715位為: o, 二進制為: 1101111
# 第716位為: g, 二進制為: 1100111
# 第717位為: r, 二進制為: 1110010
# 第718位為: a, 二進制為: 1100001
# 第719位為: p, 二進制為: 1110000
# 第720位為: h, 二進制為: 1101000
# 第721位為: y, 二進制為: 1111001
# 第722位為: N, 二進制為: 1001110
# 第723位為: I, 二進制為: 1001001
# 第724位為: U, 二進制為: 1010101
# 第725位為: 1, 二進制為: 0110001
# 第726位為: 1, 二進制為: 0110001
# 第727位為: 1, 二進制為: 0110001
# 第728位為: 2, 二進制為: 0110010
# 第729位為: C, 二進制為: 1000011
# 第730位為: r, 二進制為: 1110010
# 第731位為: y, 二進制為: 1111001
# 第732位為: p, 二進制為: 1110000
# 第733位為: t, 二進制為: 1110100
# 第734位為: o, 二進制為: 1101111
# 第735位為: g, 二進制為: 1100111
# 第736位為: r, 二進制為: 1110010
# 第737位為: a, 二進制為: 1100001
# 第738位為: p, 二進制為: 1110000
# 第739位為: h, 二進制為: 1101000
# 第740位為: y, 二進制為: 1111001
# 第741位為: N, 二進制為: 1001110
# 第742位為: I, 二進制為: 1001001
# 第743位為: U, 二進制為: 1010101
# 第744位為: 1, 二進制為: 0110001
# 第745位為: 1, 二進制為: 0110001
# 第746位為: 1, 二進制為: 0110001
# 第747位為: 2, 二進制為: 0110010
# 第748位為: C, 二進制為: 1000011
# 第749位為: r, 二進制為: 1110010
# 第750位為: y, 二進制為: 1111001
# 第751位為: p, 二進制為: 1110000
# 第752位為: t, 二進制為: 1110100
# 第753位為: o, 二進制為: 1101111
# 第754位為: g, 二進制為: 1100111
# 第755位為: r, 二進制為: 1110010
# 第756位為: a, 二進制為: 1100001
# 第757位為: p, 二進制為: 1110000
# 第758位為: h, 二進制為: 1101000
# 第759位為: y, 二進制為: 1111001
# 第760位為: N, 二進制為: 1001110
# 第761位為: I, 二進制為: 1001001
# 第762位為: U, 二進制為: 1010101
# 第763位為: 1, 二進制為: 0110001
# 第764位為: 1, 二進制為: 0110001
# 第765位為: 1, 二進制為: 0110001
# 第766位為: 2, 二進制為: 0110010
# 第767位為: C, 二進制為: 1000011
# 第768位為: r, 二進制為: 1110010
# 第769位為: y, 二進制為: 1111001
# 第770位為: p, 二進制為: 1110000
# 第771位為: t, 二進制為: 1110100
# 第772位為: o, 二進制為: 1101111
# 第773位為: g, 二進制為: 1100111
# 第774位為: r, 二進制為: 1110010
# 第775位為: a, 二進制為: 1100001
# 第776位為: p, 二進制為: 1110000
# 第777位為: h, 二進制為: 1101000
# 第778位為: y, 二進制為: 1111001
# 第779位為: N, 二進制為: 1001110
# 第780位為: I, 二進制為: 1001001
# 第781位為: U, 二進制為: 1010101
# 第782位為: 1, 二進制為: 0110001
# 第783位為: 1, 二進制為: 0110001
# 第784位為: 1, 二進制為: 0110001
# 第785位為: 2, 二進制為: 0110010
# 第786位為: C, 二進制為: 1000011
# 第787位為: r, 二進制為: 1110010
# 第788位為: y, 二進制為: 1111001
# 第789位為: p, 二進制為: 1110000
# 第790位為: t, 二進制為: 1110100
# 第791位為: o, 二進制為: 1101111
# 第792位為: g, 二進制為: 1100111
# 第793位為: r, 二進制為: 1110010
# 第794位為: a, 二進制為: 1100001
# 第795位為: p, 二進制為: 1110000
# 第796位為: h, 二進制為: 1101000
# 第797位為: y, 二進制為: 1111001
# 第798位為: N, 二進制為: 1001110
# 第799位為: I, 二進制為: 1001001
# 第800位為: U, 二進制為: 1010101
# 第801位為: 1, 二進制為: 0110001
# 第802位為: 1, 二進制為: 0110001
# 第803位為: 1, 二進制為: 0110001
# 第804位為: 2, 二進制為: 0110010
# 第805位為: C, 二進制為: 1000011
# 第806位為: r, 二進制為: 1110010
# 第807位為: y, 二進制為: 1111001
# 第808位為: p, 二進制為: 1110000
# 第809位為: t, 二進制為: 1110100
# 第810位為: o, 二進制為: 1101111
# 第811位為: g, 二進制為: 1100111
# 第812位為: r, 二進制為: 1110010
# 第813位為: a, 二進制為: 1100001
# 第814位為: p, 二進制為: 1110000
# 第815位為: h, 二進制為: 1101000
# 第816位為: y, 二進制為: 1111001
# 第817位為: N, 二進制為: 1001110
# 第818位為: I, 二進制為: 1001001
# 第819位為: U, 二進制為: 1010101
# 第820位為: 1, 二進制為: 0110001
# 第821位為: 1, 二進制為: 0110001
# 第822位為: 1, 二進制為: 0110001
# 第823位為: 2, 二進制為: 0110010
# 第824位為: C, 二進制為: 1000011
# 第825位為: r, 二進制為: 1110010
# 第826位為: y, 二進制為: 1111001
# 第827位為: p, 二進制為: 1110000
# 第828位為: t, 二進制為: 1110100
# 第829位為: o, 二進制為: 1101111
# 第830位為: g, 二進制為: 1100111
# 第831位為: r, 二進制為: 1110010
# 第832位為: a, 二進制為: 1100001
# 第833位為: p, 二進制為: 1110000
# 第834位為: h, 二進制為: 1101000
# 第835位為: y, 二進制為: 1111001
# 第836位為: N, 二進制為: 1001110
# 第837位為: I, 二進制為: 1001001
# 第838位為: U, 二進制為: 1010101
# 第839位為: 1, 二進制為: 0110001
# 第840位為: 1, 二進制為: 0110001
# 第841位為: 1, 二進制為: 0110001
# 第842位為: 2, 二進制為: 0110010
# 第843位為: C, 二進制為: 1000011
# 第844位為: r, 二進制為: 1110010
# 第845位為: y, 二進制為: 1111001
# 第846位為: p, 二進制為: 1110000
# 第847位為: t, 二進制為: 1110100
# 第848位為: o, 二進制為: 1101111
# 第849位為: g, 二進制為: 1100111
# 第850位為: r, 二進制為: 1110010
# 第851位為: a, 二進制為: 1100001
# 第852位為: p, 二進制為: 1110000
# 第853位為: h, 二進制為: 1101000
# 第854位為: y, 二進制為: 1111001
# 第855位為: N, 二進制為: 1001110
# 第856位為: I, 二進制為: 1001001
# 第857位為: U, 二進制為: 1010101
# 第858位為: 1, 二進制為: 0110001
# 第859位為: 1, 二進制為: 0110001
# 第860位為: 1, 二進制為: 0110001
# 第861位為: 2, 二進制為: 0110010
# 第862位為: C, 二進制為: 1000011
# 第863位為: r, 二進制為: 1110010
# 第864位為: y, 二進制為: 1111001
# 第865位為: p, 二進制為: 1110000
# 第866位為: t, 二進制為: 1110100
# 第867位為: o, 二進制為: 1101111
# 第868位為: g, 二進制為: 1100111
# 第869位為: r, 二進制為: 1110010
# 第870位為: a, 二進制為: 1100001
# 第871位為: p, 二進制為: 1110000
# 第872位為: h, 二進制為: 1101000
# 第873位為: y, 二進制為: 1111001
# 第874位為: N, 二進制為: 1001110
# 第875位為: I, 二進制為: 1001001
# 第876位為: U, 二進制為: 1010101
# 第877位為: 1, 二進制為: 0110001
# 第878位為: 1, 二進制為: 0110001
# 第879位為: 1, 二進制為: 0110001
# 第880位為: 2, 二進制為: 0110010
# 第881位為: C, 二進制為: 1000011
# 第882位為: r, 二進制為: 1110010
# 第883位為: y, 二進制為: 1111001
# 第884位為: p, 二進制為: 1110000
# 第885位為: t, 二進制為: 1110100
# 第886位為: o, 二進制為: 1101111
# 第887位為: g, 二進制為: 1100111
# 第888位為: r, 二進制為: 1110010
# 第889位為: a, 二進制為: 1100001
# 第890位為: p, 二進制為: 1110000
# 第891位為: h, 二進制為: 1101000
# 第892位為: y, 二進制為: 1111001
# 第893位為: N, 二進制為: 1001110
# 第894位為: I, 二進制為: 1001001
# 第895位為: U, 二進制為: 1010101
# 第896位為: 1, 二進制為: 0110001
# 第897位為: 1, 二進制為: 0110001
# 第898位為: 1, 二進制為: 0110001
# 第899位為: 2, 二進制為: 0110010
# 第900位為: C, 二進制為: 1000011
# 第901位為: r, 二進制為: 1110010
# 第902位為: y, 二進制為: 1111001
# 第903位為: p, 二進制為: 1110000
# 第904位為: t, 二進制為: 1110100
# 第905位為: o, 二進制為: 1101111
# 第906位為: g, 二進制為: 1100111
# 第907位為: r, 二進制為: 1110010
# 第908位為: a, 二進制為: 1100001
# 第909位為: p, 二進制為: 1110000
# 第910位為: h, 二進制為: 1101000
# 第911位為: y, 二進制為: 1111001
# 第912位為: N, 二進制為: 1001110
# 第913位為: I, 二進制為: 1001001
# 第914位為: U, 二進制為: 1010101
# 第915位為: 1, 二進制為: 0110001
# 第916位為: 1, 二進制為: 0110001
# 第917位為: 1, 二進制為: 0110001
# 第918位為: 2, 二進制為: 0110010
# 第919位為: C, 二進制為: 1000011
# 第920位為: r, 二進制為: 1110010
# 第921位為: y, 二進制為: 1111001
# 第922位為: p, 二進制為: 1110000
# 第923位為: t, 二進制為: 1110100
# 第924位為: o, 二進制為: 1101111
# 第925位為: g, 二進制為: 1100111
# 第926位為: r, 二進制為: 1110010
# 第927位為: a, 二進制為: 1100001
# 第928位為: p, 二進制為: 1110000
# 第929位為: h, 二進制為: 1101000
# 第930位為: y, 二進制為: 1111001
# 第931位為: N, 二進制為: 1001110
# 第932位為: I, 二進制為: 1001001
# 第933位為: U, 二進制為: 1010101
# 第934位為: 1, 二進制為: 0110001
# 第935位為: 1, 二進制為: 0110001
# 第936位為: 1, 二進制為: 0110001
# 第937位為: 2, 二進制為: 0110010
# 第938位為: C, 二進制為: 1000011
# 第939位為: r, 二進制為: 1110010
# 第940位為: y, 二進制為: 1111001
# 第941位為: p, 二進制為: 1110000
# 第942位為: t, 二進制為: 1110100
# 第943位為: o, 二進制為: 1101111
# 第944位為: g, 二進制為: 1100111
# 第945位為: r, 二進制為: 1110010
# 第946位為: a, 二進制為: 1100001
# 第947位為: p, 二進制為: 1110000
# 第948位為: h, 二進制為: 1101000
# 第949位為: y, 二進制為: 1111001
# 第950位為: N, 二進制為: 1001110
# 第951位為: I, 二進制為: 1001001
# 第952位為: U, 二進制為: 1010101
# 第953位為: 1, 二進制為: 0110001
# 第954位為: 1, 二進制為: 0110001
# 第955位為: 1, 二進制為: 0110001
# 第956位為: 2, 二進制為: 0110010
# 第957位為: C, 二進制為: 1000011
# 第958位為: r, 二進制為: 1110010
# 第959位為: y, 二進制為: 1111001
# 第960位為: p, 二進制為: 1110000
# 第961位為: t, 二進制為: 1110100
# 第962位為: o, 二進制為: 1101111
# 第963位為: g, 二進制為: 1100111
# 第964位為: r, 二進制為: 1110010
# 第965位為: a, 二進制為: 1100001
# 第966位為: p, 二進制為: 1110000
# 第967位為: h, 二進制為: 1101000
# 第968位為: y, 二進制為: 1111001
# 第969位為: N, 二進制為: 1001110
# 第970位為: I, 二進制為: 1001001
# 第971位為: U, 二進制為: 1010101
# 第972位為: 1, 二進制為: 0110001
# 第973位為: 1, 二進制為: 0110001
# 第974位為: 1, 二進制為: 0110001
# 第975位為: 2, 二進制為: 0110010
# 第976位為: C, 二進制為: 1000011
# 第977位為: r, 二進制為: 1110010
# 第978位為: y, 二進制為: 1111001
# 第979位為: p, 二進制為: 1110000
# 第980位為: t, 二進制為: 1110100
# 第981位為: o, 二進制為: 1101111
# 第982位為: g, 二進制為: 1100111
# 第983位為: r, 二進制為: 1110010
# 第984位為: a, 二進制為: 1100001
# 第985位為: p, 二進制為: 1110000
# 第986位為: h, 二進制為: 1101000
# 第987位為: y, 二進制為: 1111001
# 第988位為: N, 二進制為: 1001110
# 第989位為: I, 二進制為: 1001001
# 第990位為: U, 二進制為: 1010101
# 第991位為: 1, 二進制為: 0110001
# 第992位為: 1, 二進制為: 0110001
# 第993位為: 1, 二進制為: 0110001
# 第994位為: 2, 二進制為: 0110010
# 第995位為: C, 二進制為: 1000011
# 第996位為: r, 二進制為: 1110010
# 第997位為: y, 二進制為: 1111001
# 第998位為: p, 二進制為: 1110000
# 第999位為: t, 二進制為: 1110100
# 第1000位為: o, 二進制為: 1101111
# 第1001位為: g, 二進制為: 1100111
# 第1002位為: r, 二進制為: 1110010
# 第1003位為: a, 二進制為: 1100001
# 第1004位為: p, 二進制為: 1110000
# 第1005位為: h, 二進制為: 1101000
# 第1006位為: y, 二進制為: 1111001
# 第1007位為: N, 二進制為: 1001110
# 第1008位為: I, 二進制為: 1001001
# 第1009位為: U, 二進制為: 1010101
# 第1010位為: 1, 二進制為: 0110001
# 第1011位為: 1, 二進制為: 0110001
# 第1012位為: 1, 二進制為: 0110001
# 第1013位為: 2, 二進制為: 0110010
# 第1014位為: C, 二進制為: 1000011
# 第1015位為: r, 二進制為: 1110010
# 第1016位為: y, 二進制為: 1111001
# 第1017位為: p, 二進制為: 1110000
# 第1018位為: t, 二進制為: 1110100
# 第1019位為: o, 二進制為: 1101111
# 第1020位為: g, 二進制為: 1100111
# 第1021位為: r, 二進制為: 1110010
# 第1022位為: a, 二進制為: 1100001
# 第1023位為: p, 二進制為: 1110000
# 輸出為：...
# 字元數：1024
# 位元數：7168

# %%
#設定共享密鑰δ
key=3
keyIndex=key-1

# %% [markdown]
# ### 通用函數
#
# #### 取得資訊
#
# getACharMessage(message,index) 取得單一字元二元序列
#
# #### 區塊切割
#
# 1. showBlock(block) 打印7*7區塊
# 2. makeBlock(startx,starty,image) 將原始圖像切分成7*7大小的區塊
# 3. pixelToBinary(pixel) 像素轉成二維陣列
# 4. turnBlocksToBinary(block) 像素區塊轉二元序列
#
# #### LSB提取
#
# binaryToLSB(binary) 取得LSB
#
# #### 奇同位修改
#
# 1. XOR(a,b,c) 三位元XOR運算
# 2. oddParityCheckRow(row) 一列的奇同位修改
# 3. coverBlock(LSBBlock) 生成掩護圖像
#
# #### 找尋嵌入訊息位置
#
# 1. getShareSecretPosition(rowIndex,lastSecretIndex,embeddedIndex) 共享秘密位置 κi
# 2. chooseEmbeddeedIndex(row,secretPosition,message) 選擇嵌入位置
# 3. embeddLSBBlock(LSBBlock,message) 嵌入訊息到LSB區塊
#
# #### 區塊復原
#
# 1. reviseBinaryBlock(index,binaryPixelBlocks,LSBBlocks) LSB區塊修改二元序列區塊的最後一個位元
# 2. revisePixelBlock(index,binaryPixelBlocks,pixelBlocks) 二元序列區塊還原成十進制像素區塊
#
# #### 區塊復原到像素
#
# putPixelBlockBack(startx,starty,pixelBlock,hidedImage) 將區塊復原到隱藏訊息影像陣列
#
# #### 儲存影藏訊息陣列成圖像
#
# storeImage(hidedImage,path) 儲存隱藏訊息圖像
#
# #### PSNR
#
# psnr(originImage,hidedImage) 計算 psnr
#
# #### 相對熵
#
# hxx_forward(x, y) 計算相對熵

# %%
# 打印7*7區塊
def showBlock(block):
    for row in block:
        for element in row:
            print(element,end=' ')
        print()
    print('\n-----------------------------------------\n')

# %%
# 將原始圖像切分成7*7大小的區塊
def makeBlock(startx,starty,image):
    block=[]
    for row in range(7):
        block.append(image[startx+row][starty:starty+7])
    # showBlock(block)
    return block

# %%
# 像素轉成二維陣列
def pixelToBinary(pixel):
    return str(bin(pixel).replace('0b','').zfill(8))

# %%
# 像素區塊轉二元序列
def turnBlocksToBinary(block):
    binaryPixelBlock=[]
    for row in block:
        binaryRow=[]
        for pixel in row:
            binaryRow.append(pixelToBinary(pixel))
        binaryPixelBlock.append(binaryRow)

    # showBlock(binaryPixelBlock)
    return binaryPixelBlock

# %%
# 取得LSB
def binaryToLSB(binary):
    return int(binary[-1])

# %%
# 三位元XOR運算
def XOR(a,b,c):
    string=str(a)+str(b)+str(c)
    switcher = {
        '000': 0,
        '001': 1,
        '010': 1,
        '011': 0,
        '100': 1,
        '101': 0,
        '110': 0,
        '111': 1
    }
    return switcher.get(string, 0)

# %%
# 將二元序列區塊轉換LSB區塊
def turnBinaryBlockToLSBBlock(binaryBlock):
    LSBPixelBlock=[]
    for row in binaryBlock:
        LSBRow=[]
        for binaryPixel in row:
            LSBRow.append(binaryToLSB(binaryPixel))
        LSBPixelBlock.append(LSBRow)
    # showBlock(LSBPixelBlock)
    return LSBPixelBlock

# %%
# 一列的奇同位修改
def oddParityCheckRow(row):
    opcRow=row
    if(int(XOR(row[2],row[4],row[6]))==1):
        opcRow[0]=0
    if(int(XOR(row[2],row[5],row[6]))==0):
        opcRow[1]=1
    if(int(XOR(row[4],row[5],row[6]))==0):
        row[3]=1
    return opcRow

# %%
# 生成掩護圖像
def coverBlock(LSBBlock):
    # print('原始區塊: ')
    # showBlock(LSBBlock)
    for index,LSBRow in enumerate(LSBBlock):
        LSBBlock[index]=oddParityCheckRow(LSBRow)
    # print('奇同位修改區塊: ')
    # showBlock(LSBBlock)

# %%
#共享秘密位置 κi 
def getShareSecretPosition(rowIndex,lastSecretIndex,embeddedIndex):
    if(rowIndex==0):
        return int(key%7)
    else:
        return int((key*lastSecretIndex*embeddedIndex)%7)
    return 0

# %%
# 選擇嵌入位置
def chooseEmbeddeedIndex(row,secretPosition,message):
    indexPossible=[i for i in range(7)]
    
    #去除共享秘密位置 κi
    indexPossible.remove(secretPosition)
    
    for index,value in enumerate(row):
        if(index==secretPosition):
            continue
        if(value==message):
            indexPossible.remove(index)

    if(len(indexPossible)==0):
        return secretPosition

    return random.choice(indexPossible)

# %%
# 嵌入訊息到LSB區塊
def embeddLSBBlock(LSBBlock,message):
    lastSecretIndex=0
    embeddedIndex=0
    for index,row in enumerate(LSBBlock):
        lastSecretIndex=getShareSecretPosition(index,lastSecretIndex,embeddedIndex)
        #翻轉位元
        row[lastSecretIndex]=abs(int(row[lastSecretIndex])-1)
        embeddedIndex=chooseEmbeddeedIndex(row,lastSecretIndex,int(message[index]))
        row[embeddedIndex]=message[index]

# %%
#取得單一字元二元序列
def getACharMessage(message,index):
    return message[(index*7):(index*7)+7]

# %%
#LSB區塊修改二元序列區塊的最後一個位元
def reviseBinaryBlock(index,binaryPixelBlocks,LSBBlocks):
    binaryBlock=binaryPixelBlocks[index]
    LSBBlock=LSBBlocks[index]
    for blockRowIndex in range(7):
        binaryBlockRow=binaryBlock[blockRowIndex]
        LSBBlockRow=LSBBlock[blockRowIndex]
        for elementIndex in range(7):
            binaryBlockRow[elementIndex]=binaryBlockRow[elementIndex][:-1]+str(LSBBlockRow[elementIndex])
        binaryBlock[blockRowIndex]=binaryBlockRow
    binaryPixelBlocks[index]=binaryBlock

# %%
# 二元序列區塊還原成十進制像素區塊
def revisePixelBlock(index,binaryPixelBlocks,pixelBlocks):
    binaryBlock=binaryPixelBlocks[index]
    pixelBlock=pixelBlocks[index]
    for blockRowIndex in range(7):
        binaryBlockRow=binaryBlock[blockRowIndex]
        BlockRow=pixelBlock[blockRowIndex]
        for elementIndex in range(7):
            BlockRow[elementIndex]=int(binaryBlockRow[elementIndex],2)   
        pixelBlock[blockRowIndex]=BlockRow
    pixelBlocks[index]=pixelBlock

# %%
# 將區塊復原到隱藏訊息影像陣列
def putPixelBlockBack(startx,starty,pixelBlock,hidedImage):
    for i in range(7):
        for j in range(7):
            hidedImage[starty*7+j][startx*7+i]=pixelBlock[j][i]

# %%
# 儲存隱藏訊息圖像
def storeImage(hidedImage,path):
    hidedImage=pd.DataFrame(hidedImage)
    cv2.imwrite(path,hidedImage.to_numpy())

# %%
# 計算 psnr
def psnr(originImage,hidedImage):
   diffrence = originImage-hidedImage
   mse = np.mean(np.square(diffrence))
   psnr = 10 * np.log10(255 * 255 / mse)
   return(psnr)

# %%
#計算相對熵
def hxx_forward(x, y):
    return skm.mutual_info_score(x, y)

def hxx(x, y):
    size = x.shape[-1]
    px = np.histogram(x, 256, (0, 255))[0] / size
    py = np.histogram(y, 256, (0, 255))[0] / size
    hx = - np.sum(px * np.log(px + 1e-8))
    hy = - np.sum(py * np.log(py + 1e-8))
 
    hxy = np.histogram2d(x, y, 256, [[0, 255], [0, 255]])[0]
    hxy /= (1.0 * size)
    hxy = - np.sum(hxy * np.log(hxy + 1e-8))
 
    r = hx + hy - hxy
    return r

# %% [markdown]
# ### 單一影像生成
#
# #### 輸入
#
#  testImage: 單一圖像
#
#  message: 隱藏訊息
#
#  prt: 是否顯示提示
#
#  path: 隱藏圖像儲存路徑

# %%
def PRDHHCSingle(testImage,message,prt,path):
    pixelBlocks=[]
    binaryPixelBlocks=[]
    LSBBlocks=[]
    blockWidth=int(testImage.shape[0]/7)
    blockHeight=int(testImage.shape[1]/7)
    blocksSize=blockWidth*blockHeight

    #切分原始區塊
    if(prt==True):
        print('原圖像素: '+str(testImage.shape))
        print("區塊數量: "+str(blockWidth)+' * '+str(blockHeight))
        print("總區塊數量: "+str(blocksSize))
    
    for startx in range(blockWidth):
        for starty in range(blockHeight):
            pixelBlocks.append(makeBlock(starty*7,startx*7,testImage))

    if(prt==True):
        print("實際總區塊數量: "+str(len(pixelBlocks)))

    #像素轉二維陣列
    binaryPixelBlocks=[]
    for pixelBlock in pixelBlocks:
        binaryPixelBlocks.append(turnBlocksToBinary(pixelBlock))
    
    if(prt==True):
        print("二維區塊數: "+str(len(binaryPixelBlocks)))

    #取得LSB區塊
    LSBBlocks=[]
    for binaryBlock in binaryPixelBlocks:
        LSBBlocks.append(turnBinaryBlockToLSBBlock(binaryBlock))

    if(prt==True):  
        print("LSB區塊數: "+str(len(LSBBlocks)))
    
    # 奇同位修改
    for LSBBlock in LSBBlocks:
        coverBlock(LSBBlock)
    
    if(prt==True):  
        print("奇同位修改完成")

    # 嵌入訊息
    for index,LSBBlock in enumerate(LSBBlocks):
        embeddLSBBlock(LSBBlock,getACharMessage(message,index))
    if(prt==True):  
        print("嵌入訊息完成")

    #LSB復原到像素區塊
    for index in range(blocksSize):
        reviseBinaryBlock(index,binaryPixelBlocks,LSBBlocks)#LSB復原到二進制區塊
        revisePixelBlock(index,binaryPixelBlocks,pixelBlocks)#二進制復原到像素區塊
    if(prt==True):  
        print("LSB復原到像素區塊完成")

    # 建立空影像
    hidedImage=[]
    for index in range(224):
        row=[225 for i in range(224)]
        hidedImage.append(row)
    for index,block in enumerate(pixelBlocks):
        putPixelBlockBack(int(index/32),int(index%32),block,hidedImage)
    if(prt==True):  
        print("隱藏圖像像素陣列建立完成")

    storeImage(hidedImage,path)
    if(prt==True):  
        print("隱藏圖像儲存完成，路徑為"+str(path))

    # 計算 psnr
    hidedImage = cv2.imread(path)
    hidedImage = cv2.cvtColor(hidedImage,cv2.COLOR_BGR2GRAY) 
    if(prt==True):  
        print('psnr= '+str(psnr(testImage,hidedImage))) #57

    # 計算 相對熵(Relative Entropy)
    x = np.reshape(hidedImage, -1)
    y = np.reshape(testImage, -1)
    
    if(prt==True):  
        print('相對熵= '+str(hxx_forward(x, y)))
    
    return psnr(testImage,hidedImage),hxx_forward(x, y)

# %%
PRDHHCSingle(testImage,message,True,'../database/PRDHHC/test.jpg')
# Out:
# 原圖像素: (224, 224)
# 區塊數量: 32 * 32
# 總區塊數量: 1024
# 實際總區塊數量: 1024
# 二維區塊數: 1024
# LSB區塊數: 1024
# 奇同位修改完成
# 嵌入訊息完成
# LSB復原到像素區塊完成
# 隱藏圖像像素陣列建立完成
# 隱藏圖像儲存完成，路徑為../database/PRDHHC/test.jpg
# psnr= 51.551846388872164
# 相對熵= 4.125020806553498
# (51.551846388872164, 4.125020806553498)

# %%
PRDHHCSingle(testImage,message,False,'../database/PRDHHC/test.jpg')
# Out:
# (51.59775532397373, 4.119600880893148)

# %% [markdown]
# ### 多個影像生成
#
# #### 輸入
#
#  message: 隱藏訊息
#
#  prt: 是否顯示提示
#
#  dirPath: 隱藏圖像儲存路徑

# %%
def getResizeImageArray():
    imageResizeArray=[]
    imageArray,imageArrayLength=getImageArray('../database/resizeImage')
    for image in imageArray:
        imageResizeArray.append(cv2.cvtColor(image,cv2.COLOR_BGR2GRAY))
    return imageResizeArray,imageArrayLength

# %%
def writeCSV(array,fileName):
    with open(fileName, 'w', newline='') as csvfile:
        # 以空白分隔欄位，建立 CSV 檔寫入器
        writer = csv.writer(csvfile, delimiter=',')

        writer.writerow(['PRDHHC'])
        for number in array:
            writer.writerow([number])
    csvfile.close()

# %%
def PRDHHCMultiple(message,prt,dirPath):
    psnrArray=[]
    hxxArray=[]
    #取得圖片陣列
    imageArray,imageArrayLength=getResizeImageArray()
    for index in range(imageArrayLength):
        psnr,hxx=PRDHHCSingle(imageArray[index],message,prt,dirPath+str(index+1)+'.jpg')
        psnrArray.append(psnr)
        hxxArray.append(hxx)
    
    if(prt):
        print(psnrArray)
        print(hxxArray)
    
    writeCSV(psnrArray,'./PSNR.csv')
    writeCSV(hxxArray,'./hxx.csv')

# %%
PRDHHCMultiple(message,False,'./database/')
